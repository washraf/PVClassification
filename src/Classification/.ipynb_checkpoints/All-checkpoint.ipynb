# %% [markdown]
# # Classification Process

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#
# Importing the Necessary Libraries<br></p>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


#Classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle

import time

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#
# Creating a Pandas DataFrame from a CSV file<br></p>

# %%
def CreateDataFrame(types,subtype, level):
    data = pd.read_csv('../Extraction/'+types+"/"+subtype+"/"+level+'.csv')
    data["Class"] = level
    return data

# %%
def LoadFullData(types,subtype):
    if(subtype=="All"):
        frames = [CreateDataFrame(types,"Roof","Clean"), 
              CreateDataFrame(types,"Roof","Dirty (0-20)"), 
              CreateDataFrame(types,"Roof","Dirty (20-40)"), 
              CreateDataFrame(types,"Roof","Dirty (40-60)"),
              CreateDataFrame(types,"Roof","Dirty (60-80)"),
              CreateDataFrame(types,"Roof","Dirty (80-100)"),
              CreateDataFrame(types,"Grass","Clean"), 
              CreateDataFrame(types,"Grass","Dirty (0-20)"), 
              CreateDataFrame(types,"Grass","Dirty (20-40)"), 
              CreateDataFrame(types,"Grass","Dirty (40-60)"),
              CreateDataFrame(types,"Grass","Dirty (60-80)"),
              CreateDataFrame(types,"Grass","Dirty (80-100)")]
    else:
        frames = [CreateDataFrame(types,subtype,"Clean"), 
              CreateDataFrame(types,subtype,"Dirty (0-20)"), 
              CreateDataFrame(types,subtype,"Dirty (20-40)"), 
              CreateDataFrame(types,subtype,"Dirty (40-60)"),
              CreateDataFrame(types,subtype,"Dirty (60-80)"),
              CreateDataFrame(types,subtype,"Dirty (80-100)")]
    df = pd.concat(frames)
    #Randomize
    df = shuffle(df)
    y=df[['Class']].copy()
    X = df.copy()
    del X['Class']
    f = df[['FileAddress']].copy()
    del X['FileAddress']
    return X,y,f

# %%
def LoadMinimizedData(types,subtype, count):
    df = pd.read_csv('../Selection/Selection-'+types+"-"+subtype+"-"+count+".csv")
    y=df[['Class']].copy()
    X = df.copy()
    del X['Class']
    f = df[['FileAddress']].copy()
    del X['FileAddress']
    return X,y,f

# %%
def loader(types,subtype,datasize):
    if(datasize=="Full"):
        X,y,f = LoadFullData(types,subtype)
    else:
        count = datasize.split('-')[-1]
        X,y,f = LoadMinimizedData(types,subtype,count)
    return X,y,f

# %% [markdown]
# # Classifications

# %% [markdown]
# ## Optimize KNN Classfiers

# %%
def optimizeKNN(X_train, y_train,cv):
    param_grid = [{'clf__weights': ["distance"], 'clf__n_neighbors': [5]}]
    clfpipeline = Pipeline([
        ('scale', StandardScaler()),
        ('clf', KNeighborsClassifier())
    ])
    grid_search = GridSearchCV(clfpipeline, param_grid, cv=cv, verbose=3, n_jobs=-1)
    grid_search.fit(X_train, y_train.values.ravel())
    end = time.time()
    return grid_search

# %% [markdown]
# ## Optimize SVM Classfiers

# %%
def optimizeSVM(X_train, y_train,cv):
    param_grid = [
            {'clf__kernel': ['poly'],'clf__degree':[1,5],'clf__coef0':[5,10]}
            #,{'clf__kernel': ['rbf'],'clf__gamma': [0.01, 0.03, 0.1, 0.3, 1.0, 3.0]}
            #,{'clf__kernel': ['sigmoid'],'clf__coef0':[1,5,10,15,20,30]}
            #,{'clf__kernel':['linear'],'clf__C':[1,5,10]}
            ]

    clfpipeline = Pipeline([
        ('scale', StandardScaler()),
        ('clf', SVC())
    ])
    grid_search = GridSearchCV(clfpipeline, param_grid, cv=cv, verbose=3, n_jobs=-1)
    grid_search.fit(X_train, y_train.values.ravel())
    return grid_search

# %% [markdown]
# ## Optimize Random Forest Classfiers

# %%
def optimizeRandomForest(X_train, y_train,cv):
    param_grid = [
            {'clf__n_estimators': [30],'clf__max_features':['auto']},
            ]

    clfpipeline = Pipeline([
        ('scale', StandardScaler()),
        ('clf', RandomForestClassifier())])
        
    grid_search = GridSearchCV(clfpipeline, param_grid, cv=cv, verbose=3, n_jobs=-1)
    grid_search.fit(X_train, y_train.values.ravel())
    return grid_search

# %% [markdown]
# ## Optimize NN Classifiers

# %%
def optimizeNN(X_train, y_train,cv):
    param_grid = [{'clf__hidden_layer_sizes': [(100,50,30,)]}]
    clfpipeline = Pipeline([
        ('scale', StandardScaler()),
        ('clf', MLPClassifier())
    ])
    grid_search = GridSearchCV(clfpipeline, param_grid, cv=cv, verbose=3, n_jobs=-1)
    grid_search.fit(X_train, y_train.values.ravel())
    return grid_search

# %% [markdown]
# ## Cycle Work

# %%
def cycleWork(X_train, X_test, y_train, y_test,optimize,cv):
    gridsearch = optimize(X_train, y_train,cv)
    traintime = gridsearch.cv_results_['mean_fit_time'].mean()*1000
    print("Mean Fit Time", traintime)
    print("Mean Score Time", gridsearch.cv_results_['mean_score_time'].mean()*1000)

    #print(gridsearch.best_params_)
    estimator = gridsearch.best_estimator_
    params = estimator.get_params()['clf']
    print(params)
    y_train_pred = estimator.predict(X_train)
    trnscore = accuracy_score(y_train, y_train_pred)
    start = time.time()
    y_tst_pred = estimator.predict(X_test)
    end = time.time()
    diff = end-start
    clfperms = X_train.shape[0]/((diff*1000)+0.000000001)
    tstscore = accuracy_score(y_test, y_tst_pred)
    cm = confusion_matrix(y_test, y_tst_pred)
    true_pos = np.diag(cm) 
    precision = np.sum(true_pos / np.sum(cm, axis=0))
    recall = np.sum(true_pos / np.sum(cm, axis=1))
    f1 = 2 * ((precision* recall)/(precision + recall))
    #f1None = f1_score(y_test, y_tst_pred, average=None)
    #f1micro = f1_score(y_test, y_tst_pred, average='micro')
    return [trnscore, tstscore, f1,traintime,clfperms,cm,params,estimator]

# %%
def saveresultlist(types,subtype,datasize,clf,iteration,split,classifier,X,y,files):
    data = []
    #print(files.shape[0])
    for i in range(0,files.shape[0]):
        #print(files.iloc[[i]])
        #print(X.iloc[[i]])
        pred = classifier.predict(X.iloc[[i]])
        #print(pred)
        data.append([files.iloc[[i]].values[0][0],y.iloc[[i]].values[0][0],pred[0]])
    numpyarray = np.array(data)
    df = pd.DataFrame(numpyarray, columns = ["File","Y","Pred"])
    fileName = "Real-"+types+'-'+ subtype+"-"+ datasize+"-"+ str(clf)+"-"+ str(iteration)+"-"+ str(split)+'.csv'
    print(type(fileName))
    df.to_csv(fileName,index = False)

# %%
def AllWork(types,subtype,sizeDict, cycles = 5, out=False,cross_validation=5):    
    data = []
    for datasize in sizeDict:
        print(datasize)
        classifiersDict = {
                        "KNN":optimizeKNN,
                        "SVM":optimizeSVM,
                        "RF":optimizeRandomForest,
                        "NN":optimizeNN
                          }
        for clf in classifiersDict:
            for i in range(0,cycles):
                X,y,f = loader(types,subtype,datasize)
                #X,y = LoadMinimizedData(types)
                skf = StratifiedKFold(n_splits=cross_validation,shuffle = True)
                j = 0
                for train_index, test_index in skf.split(X, y.values.ravel()):
                    print("Size ",datasize, " Algorithm ",clf, " Trial ",i, " Split ", j," :")
                    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
                    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
                    acc = cycleWork(X_train, X_test, y_train, y_test,classifiersDict[clf],cross_validation)
                    saveresultlist(types,subtype,datasize,clf,i,j,acc[7],X,y,f)
                    print("Train Accuracy ",acc[0],", Test Accuracy",acc[1], "F1 ",acc[2])
                    data.append([clf,datasize.split('-')[-1],i,j,acc[0],acc[1],acc[2],acc[3],acc[4],acc[5],acc[6]])
                    j = j+1
                    break
                    print("########################################")
    numpyarray = np.array(data)
    df = pd.DataFrame(numpyarray, columns = ["Classifier","Count","Cycle","Split","Train Acc", "Test Acc", "F1 Score","Train Time (ms)","clfs per ms","Confusion Matrix","Params"])
    if(out):
        df.to_csv("All-"+types+'-'+subtype+'.csv',index = False)
    df.head(10)

# %%
types = "Cropped"
subtype = "All"
cycles = 1
sizeDict = {
                "Full":None,
                "Min-10":10,
                #"Min-20":20,
                #"Min-30":30,
                #"Min-40":40
                }
AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=5)
# Out:
# Full
# Size  Full  Algorithm  KNN  Trial  0  Split  0  :
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.5s remaining:    8.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.2s finished
# Mean Fit Time 72.70069122314453
# Mean Score Time 200.89950561523438
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.972072072072072 F1  5.8214574310696
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  1  :
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.5s remaining:   15.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   17.5s finished
# Mean Fit Time 95.2998161315918
# Mean Score Time 204.50105667114258
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.9522522522522523 F1  5.734356751433114
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  2  :
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.4s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.3s finished
# Mean Fit Time 60.69908142089844
# Mean Score Time 143.2994842529297
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.9611913357400722 F1  5.767867664772448
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  3  :
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    8.5s remaining:   12.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.6s finished
# Mean Fit Time 79.10146713256836
# Mean Score Time 219.09832954406738
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.9512195121951219 F1  5.71356987528095
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  4  :
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.2s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    9.2s finished
# Mean Fit Time 44.69866752624512
# Mean Score Time 108.20016860961914
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.9529837251356239 F1  5.718260710238654
# ########################################
# Size  Full  Algorithm  SVM  Trial  0  Split  0  :
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   29.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   29.8s finished
# Mean Fit Time 1896.724271774292
# Mean Score Time 238.6760711669922
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=10,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# <class 'str'>
# Train Accuracy  1.0 , Test Accuracy 0.981081081081081 F1  5.884860208359644
# ########################################
# Size  Full  Algorithm  SVM  Trial  0  Split  1  :
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   24.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   24.7s finished
# Mean Fit Time 1556.4743161201475
# Mean Score Time 188.27550411224365
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=10,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-6cb1bc8edc76> in <module>()
#       9                 #"Min-40":40
#      10                 }
# ---> 11 AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=5)
#
# <ipython-input-81-30b24fdf4812> in AllWork(types, subtype, sizeDict, cycles, out, cross_validation)
#      20                     y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#      21                     acc = cycleWork(X_train, X_test, y_train, y_test,classifiersDict[clf],cross_validation)
# ---> 22                     saveresultlist(types,subtype,datasize,clf,i,j,acc[7],X,y,f)
#      23                     print("Train Accuracy ",acc[0],", Test Accuracy",acc[1], "F1 ",acc[2])
#      24                     data.append([clf,datasize.split('-')[-1],i,j,acc[0],acc[1],acc[2],acc[3],acc[4],acc[5],acc[6]])
#
# <ipython-input-80-d084c25c1170> in saveresultlist(types, subtype, datasize, clf, iteration, split, classifier, X, y, files)
#       5         #print(files.iloc[[i]])
#       6         #print(X.iloc[[i]])
# ----> 7         pred = classifier.predict(X.iloc[[i]])
#       8         #print(pred)
#       9         data.append([files.iloc[[i]].values[0][0],y.iloc[[i]].values[0][0],pred[0]])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     113
#     114         # lambda, but not partial, allows help() to work with update_wrapper
# --> 115         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     116         # update the docstring of the returned function
#     117         update_wrapper(out, self.fn)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X)
#     304         for name, transform in self.steps[:-1]:
#     305             if transform is not None:
# --> 306                 Xt = transform.transform(Xt)
#     307         return self.steps[-1][-1].predict(Xt)
#     308
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X, y, copy)
#     679         copy = copy if copy is not None else self.copy
#     680         X = check_array(X, accept_sparse='csr', copy=copy, warn_on_dtype=True,
# --> 681                         estimator=self, dtype=FLOAT_DTYPES)
#     682
#     683         if sparse.issparse(X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# KeyboardInterrupt:

# %%
types = "Solar Data"
cycles = 1
subtype = "All"
sizeDict = {
                "Full":None,
                "Min-10":10,
                #"Min-20":20,
                #"Min-30":30,
                #"Min-40":40
                }
AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=5)
#subtype = "Grass"
#AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=10)
#subtype = "Roof"
#AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=10)
# Out:
# Full
# Size  Full  Algorithm  KNN  Trial  0  Split  0  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    8.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.7s finished
# Mean Fit Time 96.35009765625
# Mean Score Time 92.1511173248291
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9820466786355476 F1  5.899442558143364
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  1  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   12.1s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   13.3s finished
# Mean Fit Time 104.09984588623047
# Mean Score Time 114.49925899505615
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.992818671454219 F1  5.95734963195095
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  2  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   10.9s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   11.9s finished
# Mean Fit Time 93.99986267089844
# Mean Score Time 93.30074787139893
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9856373429084381 F1  5.917385588966903
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    8.8s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.4s finished
# Mean Fit Time 62.90140151977538
# Mean Score Time 68.69947910308838
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9820143884892086 F1  5.894827353347261
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    6.9s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    7.7s finished
# Mean Fit Time 60.65084934234619
# Mean Score Time 72.44961261749268
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9801801801801802 F1  5.892746997099125
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   12.6s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   13.7s finished
# Mean Fit Time 103.99889945983887
# Mean Score Time 124.09944534301758
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9855595667870036 F1  5.91876254755457
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    8.8s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.4s finished
# Mean Fit Time 68.3018684387207
# Mean Score Time 69.39835548400879
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9873646209386282 F1  5.925515893199564
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  7  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    6.8s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    7.4s finished
# Mean Fit Time 58.29975605010986
# Mean Score Time 62.5997543334961
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9855334538878843 F1  5.914980759533862
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  8  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    6.7s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    7
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=10,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.992818671454219 F1  5.952432856736901
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  2  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   35.5s finished
# Mean Fit Time 1441.0991311073305
# Mean Score Time 115.22614359855653
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997995590298657 , Test Accuracy 0.9892280071813285 F1  5.939296393647698
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  3  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   34.7s finished
# Mean Fit Time 1519.9870645999908
# Mean Score Time 123.87673258781435
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.9910071942446043 F1  5.943988347262652
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  4  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   31.3s finished
# Mean Fit Time 1416.2736117839813
# Mean Score Time 108.27648639678955
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997996393508315 , Test Accuracy 0.9963963963963964 F1  5.97971831629841
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  5  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   37.6s finished
# Mean Fit Time 1564.5865201950073
# Mean Score Time 118.91373991966249
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.9927797833935018 F1  5.961061427074181
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  6  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   31.2s finished
# Mean Fit Time 1380.5861592292786
# Mean Score Time 98.48884344100951
# ...
# Mean Score Time 6.70161247253418
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9925836841050311 , Test Accuracy 0.9856373429084381 F1  5.920389725927323
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.5s remaining:   14.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   39.0s finished
# Mean Fit Time 11050.098896026611
# Mean Score Time 7.401418685913086
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.998997995991984 , Test Accuracy 0.9946043165467626 F1  5.967218316290982
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.2s remaining:   14.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   36.1s finished
# Mean Fit Time 11254.400539398193
# Mean Score Time 7.250022888183594
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9973953115608094 , Test Accuracy 0.9819819819819819 F1  5.9065761650366015
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.2s remaining:   14.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   36.8s finished
# Mean Fit Time 11171.651577949524
# Mean Score Time 7.350277900695801
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9981971153846154 , Test Accuracy 0.9855595667870036 F1  5.915598169404932
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   30.1s remaining:   12.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   38.7s finished
# Mean Fit Time 11126.59900188446
# Mean Score Time 9.101128578186035
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9987980769230769 , Test Accuracy 0.9945848375451264 F1  5.972300071082804
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  7  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.1s remaining:   14.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   38.2s finished
# Mean Fit Time 10670.799112319946
# Mean Score Time 7.101750373840332
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.998598037252153 , Test Accuracy 0.9801084990958409 F1  5.888712998088578
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  8  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   27.5s remaining:   11.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   37.1s finished
# Mean Fit Time 10449.400019645691
# Mean Score Time 7.451224327087402
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.999199038846616 , Test Accuracy 0.9909420289855072 F1  5.947040159979761
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  9  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   32.2s remaining:   13.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   36.5s finished
# Mean Fit Time 10607.798528671265
# Mean Score Time 9.151387214660645
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.998998998998999 , Test Accuracy 0.9927404718693285 F1  5.955676855232772
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  0  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   32.2s remaining:   13.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   41.2s finished
# Mean Fit Time 11490.49997329712
# Mean Score Time 7.500815391540527
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9981960312687913 , Test Accuracy 0.9892280071813285 F1  5.940481128374908
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  1  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   31.0s remaining:   13.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   38.0s finished
# Mean Fit Time 10911.049556732178
# Mean Score Time 8.200979232788086
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9967929444778513 , Test Accuracy 0.9838420107719928 F1  5.906410177212854
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  2  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   30.1s remaining:   12.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   35.2s finished
# Mean Fit Time 10710.250043869019
# Mean Score Time 7.202005386352539
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9987973541791942 , Test Accuracy 0.9946140035906643 F1  5.96763318666818
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   35.3s remaining:   15.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   41.3s finished
# Mean Fit Time 12163.248944282532
# Mean Score Time 8.051156997680664
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9961923847695391 , Test Accuracy 0.9928057553956835 F1  5.958172454171364
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   29.5s remaining:   12.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   39.2s finished
# Mean Fit Time 11275.64992904663
# Mean Score Time 8.70068073272705
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9961931476657985 , Test Accuracy 0.990990990990991 F1  5.950274413227124
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   34.6s remaining:   14.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   37.9s finished
# Mean Fit Time 11783.59968662262
# Mean Score Time 7.20062255859375
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9911858974358975 , Test Accuracy 0.9927797833935018 F1  5.955524084756932
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   32.0s remaining:   13.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   35.4s finished
# Mean Fit Time 10439.849138259888
# Mean Score Time 7.101750373840332
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9959935897435898 , Test Accuracy 0.9819494584837545 F1  5.894842140792812
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  7  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   34.9s remaining:   14.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   42.2s finished
# Mean Fit Time 12214.000678062439
# Mean Score Time 8.150649070739746
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9969957941117564 , Test Accuracy 0.9837251356238698 F1  5.911361853583486
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  8  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.8s remaining:   14.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   38.7s finished
# Mean Fit Time 11763.300156593323
# Mean Score Time 8.000993728637695
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9983980776932319 , Test Accuracy 0.9927536231884058 F1  5.960773046167214
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  9  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   32.8s remaining:   14.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   37.5s finished
# Mean Fit Time 11814.949989318848
# Mean Score Time 7.85048007965088
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.994994994994995 , Test Accuracy 0.9673321234119783 F1  5.824219099056151
# ########################################

# %%
types = "NoBG"
cycles = 1
subtype = "All"
sizeDict = {
                "Full":None,
                "Min-10":10,
                #"Min-20":20,
                #"Min-30":30,
                #"Min-40":40
                }
AllWork(types,subtype,sizeDict,cycles = cycles, out=True,cross_validation=5)
# Out:
# Full
# Size  Full  Algorithm  KNN  Trial  0  Split  0  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    7.8s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    8.8s finished
# Mean Fit Time 60.948944091796875
# Mean Score Time 72.70095348358154
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9712230215827338 F1  5.832934587552014
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  1  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   11.1s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   12.3s finished
# Mean Fit Time 98.4492540359497
# Mean Score Time 113.54997158050537
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9784172661870504 F1  5.8688999229274215
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  2  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   11.2s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   12.2s finished
# Mean Fit Time 94.94898319244385
# Mean Score Time 99.50001239776611
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9783783783783784 F1  5.875404511383336
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    7.6s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    8.3s finished
# Mean Fit Time 60.24961471557617
# Mean Score Time 72.75049686431885
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.972972972972973 F1  5.839627711199476
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    7.2s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    8.2s finished
# Mean Fit Time 56.2497615814209
# Mean Score Time 70.25179862976074
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9513513513513514 F1  5.716615765088981
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   11.2s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   12.3s finished
# Mean Fit Time 89.04833793640137
# Mean Score Time 101.7005205154419
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9638989169675091 F1  5.802854491265896
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   10.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   11.2s finished
# Mean Fit Time 66.04912281036377
# Mean Score Time 78.95164489746094
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='distance')
# Train Accuracy  1.0 , Test Accuracy 0.9693140794223827 F1  5.816207390819443
# ########################################
# Size  Full  Algorithm  KNN  Trial  0  Split
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.9873646209386282 F1  5.925158403861185
# ########################################
# Size  Full  Algorithm  SVM  Trial  1  Split  7  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   41.3s finished
# Mean Fit Time 2092.949104309082
# Mean Score Time 123.70145320892334
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997995188452286 , Test Accuracy 0.9819168173598554 F1  5.893683921257637
# ########################################
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   40.7s finished
# Size  Full  Algorithm  SVM  Trial  1  Split  8  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Mean Fit Time 2132.911306619644
# Mean Score Time 113.90105485916138
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9995991180597315 , Test Accuracy 0.9909420289855072 F1  5.953688367896047
# ########################################
# Size  Full  Algorithm  SVM  Trial  1  Split  9  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   45.4s finished
# Mean Fit Time 2227.801340818405
# Mean Score Time 133.7602436542511
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9995991983967936 , Test Accuracy 0.9872958257713249 F1  5.930310529686372
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  0  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   39.9s finished
# Mean Fit Time 2125.4740715026855
# Mean Score Time 113.56370449066162
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9995987963891675 , Test Accuracy 0.987410071942446 F1  5.92824484495687
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  1  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   40.0s finished
# Mean Fit Time 2053.6611199378967
# Mean Score Time 115.08870124816895
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997993981945837 , Test Accuracy 0.9856115107913669 F1  5.909746823662906
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  2  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   40.6s finished
# Mean Fit Time 2153.0614852905273
# Mean Score Time 116.91371798515321
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997994384275972 , Test Accuracy 0.9855855855855856 F1  5.922563262048938
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  3  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   39.4s finished
# Mean Fit Time 2045.9620177745821
# Mean Score Time 125.17544627189636
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.9873873873873874 F1  5.927875494847769
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  4  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   43.2s finished
# Mean Fit Time 2216.799420118332
# Mean Score Time 121.30113840103151
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=10,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  1.0 , Test Accuracy 0.9891891891891892 F1  5.942843660534881
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  5  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   40.6s finished
# Mean Fit Time 2104.023909568786
# Mean Score Time 117.18841195106505
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=5,
#   decision_function_shape='ovr', degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Train Accuracy  0.9997994786444756 , Test Accuracy 0.9909747292418772 F1  5.954706175281757
# ########################################
# Size  Full  Algorithm  SVM  Trial  2  Split  6  :
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# ...
# Mean Score Time 9.750223159790039
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.983754512635379 , Test Accuracy 0.9747747747747748 F1  5.854915949475203
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   35.5s remaining:   15.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   43.7s finished
# Mean Fit Time 12712.147855758667
# Mean Score Time 7.652902603149414
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9881668672282391 , Test Accuracy 0.9873873873873874 F1  5.924599873237708
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   36.0s remaining:   15.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   47.4s finished
# Mean Fit Time 13629.749703407288
# Mean Score Time 8.65025520324707
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9921780986762936 , Test Accuracy 0.9837837837837838 F1  5.897843113239366
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   34.1s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   41.8s finished
# Mean Fit Time 12192.24808216095
# Mean Score Time 8.402204513549805
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9871666332464407 , Test Accuracy 0.9765342960288809 F1  5.8647345466571235
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   36.9s remaining:   15.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   42.9s finished
# Mean Fit Time 12640.149068832397
# Mean Score Time 9.151101112365723
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.991177060356928 , Test Accuracy 0.9729241877256317 F1  5.851489181177169
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  7  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   34.7s remaining:   14.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   44.4s finished
# Mean Fit Time 13058.149147033691
# Mean Score Time 8.400750160217285
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9921812349639134 , Test Accuracy 0.9873417721518988 F1  5.920642703103168
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  8  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   36.6s remaining:   15.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   44.0s finished
# Mean Fit Time 12578.348588943481
# Mean Score Time 8.201193809509277
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9941872118661055 , Test Accuracy 0.980072463768116 F1  5.88895103886784
# ########################################
# Size  Min-40  Algorithm  NN  Trial  3  Split  9  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   41.1s remaining:   17.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   46.4s finished
# Mean Fit Time 14604.849886894226
# Mean Score Time 11.850833892822266
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9901803607214429 , Test Accuracy 0.9836660617059891 F1  5.908359059910582
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  0  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   36.5s remaining:   15.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   38.6s finished
# Mean Fit Time 12399.70097541809
# Mean Score Time 7.650279998779297
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9877632898696088 , Test Accuracy 0.9820143884892086 F1  5.902507779169453
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  1  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   38.1s remaining:   16.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   47.2s finished
# Mean Fit Time 13894.498300552368
# Mean Score Time 8.101296424865723
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9889669007021064 , Test Accuracy 0.9766187050359713 F1  5.867603028291716
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  2  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   35.9s remaining:   15.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   43.9s finished
# Mean Fit Time 13020.59998512268
# Mean Score Time 7.900238037109375
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9877657440834336 , Test Accuracy 0.972972972972973 F1  5.853946897992439
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  3  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   37.7s remaining:   16.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   43.7s finished
# Mean Fit Time 13326.049089431763
# Mean Score Time 9.05160903930664
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9897713598074609 , Test Accuracy 0.990990990990991 F1  5.946535994135455
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  4  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   38.0s remaining:   16.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   42.5s finished
# Mean Fit Time 12722.149682044983
# Mean Score Time 7.050085067749023
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.99338146811071 , Test Accuracy 0.9855855855855856 F1  5.905691415433187
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  5  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   43.4s remaining:   18.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   46.5s finished
# Mean Fit Time 14866.898798942566
# Mean Score Time 8.501315116882324
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9885702827351113 , Test Accuracy 0.9747292418772563 F1  5.846588467666047
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  6  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   31.8s remaining:   13.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   39.4s finished
# Mean Fit Time 10652.849459648132
# Mean Score Time 7.650518417358398
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9969921796671346 , Test Accuracy 0.9783393501805054 F1  5.8734926127114
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  7  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.9s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   37.5s finished
# Mean Fit Time 11698.149013519287
# Mean Score Time 7.750964164733887
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9931836407377707 , Test Accuracy 0.9837251356238698 F1  5.9072756458049005
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  8  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   34.1s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   36.2s finished
# Mean Fit Time 10774.748921394348
# Mean Score Time 8.200860023498535
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9909801563439568 , Test Accuracy 0.980072463768116 F1  5.880291176110103
# ########################################
# Size  Min-40  Algorithm  NN  Trial  4  Split  9  :
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   30.7s remaining:   13.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   34.5s finished
# Mean Fit Time 10091.949844360352
# Mean Score Time 7.650589942932129
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 50, 30), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# Train Accuracy  0.9849699398797596 , Test Accuracy 0.9745916515426497 F1  5.849168467092407
# ########################################
