# %% [markdown]
# * https://stackoverflow.com/questions/45483890/how-to-correctly-use-scipys-skew-and-kurtosis-functions
# * https://dsp.stackexchange.com/questions/30435/what-do-skewness-and-kurtosis-represent

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy.stats import kurtosis
from scipy.stats import skew
from skimage import color
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("GOPR0785.JPG")
img = np.array(img)
img = color.rgb2gray(img)
img = img * 255

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (995, 1368)

# %%
data = img.flatten()
index = np.argwhere(data==0)
data = np.delete(data, index)

# %%
plt.style.use('ggplot')

plt.hist(data, bins=60)
# Out:
# (array([  2.08060000e+04,   2.62000000e+02,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.00000000e+00,
#           3.10000000e+01,   1.36000000e+02,   4.42000000e+02,
#           9.80000000e+02,   1.79200000e+03,   2.55000000e+03,
#           3.27300000e+03,   4.03000000e+03,   4.27600000e+03,
#           4.14800000e+03,   4.21800000e+03,   4.02100000e+03,
#           3.92300000e+03,   3.81600000e+03,   4.00700000e+03,
#           4.06600000e+03,   3.90900000e+03,   4.05000000e+03,
#           4.49000000e+03,   5.42500000e+03,   7.43300000e+03,
#           1.13900000e+04,   1.53160000e+04,   1.96770000e+04,
#           2.94610000e+04,   6.04660000e+04,   1.04246000e+05,
#           1.32776000e+05,   1.12936000e+05,   6.43010000e+04,
#           2.54970000e+04,   1.11370000e+04,   6.38900000e+03,
#           3.83300000e+03,   2.53700000e+03,   1.74800000e+03,
#           1.50600000e+03,   1.32900000e+03,   1.14800000e+03,
#           9.44000000e+02,   8.83000000e+02,   8.62000000e+02,
#           9.22000000e+02,   9.45000000e+02,   8.55000000e+02,
#           8.41000000e+02,   7.84000000e+02,   8.23000000e+02,
#           8.87000000e+02,   5.79000000e+02,   4.16000000e+02,
#           3.20000000e+02,   2.47000000e+02,   9.45000000e+02]),
#  array([  1.44200000e-01,   4.39179667e+00,   8.63939333e+00,
#           1.28869900e+01,   1.71345867e+01,   2.13821833e+01,
#           2.56297800e+01,   2.98773767e+01,   3.41249733e+01,
#           3.83725700e+01,   4.26201667e+01,   4.68677633e+01,
#           5.11153600e+01,   5.53629567e+01,   5.96105533e+01,
#           6.38581500e+01,   6.81057467e+01,   7.23533433e+01,
#           7.66009400e+01,   8.08485367e+01,   8.50961333e+01,
#           8.93437300e+01,   9.35913267e+01,   9.78389233e+01,
#           1.02086520e+02,   1.06334117e+02,   1.10581713e+02,
#           1.14829310e+02,   1.19076907e+02,   1.23324503e+02,
#           1.27572100e+02,   1.31819697e+02,   1.36067293e+02,
#           1.40314890e+02,   1.44562487e+02,   1.48810083e+02,
#           1.53057680e+02,   1.57305277e+02,   1.61552873e+02,
#           1.65800470e+02,   1.70048067e+02,   1.74295663e+02,
#           1.78543260e+02,   1.82790857e+02,   1.87038453e+02,
#           1.91286050e+02,   1.95533647e+02,   1.99781243e+02,
#           2.04028840e+02,   2.08276437e+02,   2.12524033e+02,
#           2.16771630e+02,   2.21019227e+02,   2.25266823e+02,
#           2.29514420e+02,   2.33762017e+02,   2.38009613e+02,
#           2.42257210e+02,   2.46504807e+02,   2.50752403e+02,
#           2.55000000e+02]),
#  <a list of 60 Patch objects>)

# %%
print("mean : ", np.mean(data))
# Out:
# mean :  133.128111066

# %%
print("var  : ", np.var(data))
# Out:
# var  :  1104.3952565

# %%
print("skew : ",skew(data))
# Out:
# skew :  -2.021914005143601

# %%
print("kurt : ",kurtosis(data))
# Out:
# kurt :  6.646991196170042
