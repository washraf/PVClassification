# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
resultsNOBG = pd.read_csv('../Classification/All-NoBG.csv', sep=',')
resultsSolar= pd.read_csv('../Classification/All-Solar Data.csv', sep=',')
#type(results)

# %%
resultsNOBG['Train Acc'] = resultsNOBG['Train Acc'] *100
resultsNOBG['Test Acc'] = resultsNOBG['Test Acc'] *100
resultsSolar['Train Acc'] = resultsSolar['Train Acc'] *100
resultsSolar['Test Acc'] = resultsSolar['Test Acc'] *100

# %%
from matplotlib import rc

# Set the global font to be DejaVu Sans, size 10 (or any other sans-serif font of your choice!)
rc('font',**{'family':'sans-serif','sans-serif':['DejaVu Sans'],'size':10})

# Set the font used for MathJax - more on this later
rc('mathtext',**{'default':'regular'})

from matplotlib import rcParams
rcParams['axes.titlepad'] = 4 
rcParams['xtick.labelsize'] = 14
#rcParams.keys()

# %%
# %matplotlib inline

# The following %config line changes the inline figures to have a higher DPI.
# You can comment out (#) this line if you don't have a high-DPI (~220) display.
# %config InlineBackend.figure_format = 'retina'

# %%
resultsNOBG.head()
# Out:
#   Classifier Count  Cycle  Split  Train Acc   Test Acc  F1 Score  \
# 0        KNN  Full      0      0      100.0  96.808511  5.822548
# 1        KNN  Full      0      1      100.0  97.864769  5.880301
# 2        KNN  Full      0      2      100.0  96.085409  5.789769
# 3        KNN  Full      0      3      100.0  95.683453  5.751398
# 4        KNN  Full      0      4      100.0  97.841727  5.876101
#
#    Train Time (ms)  clfs per ms  \
# 0        20.487833   125.168757
# 1        23.185992   113.838962
# 2        24.087405   125.218785
# 3        21.386671    89.549954
# 4        24.984932   119.404347
#
#                                               Params
# 0  KNeighborsClassifier(algorithm='auto', leaf_si...
# 1  KNeighborsClassifier(algorithm='auto', leaf_si...
# 2  KNeighborsClassifier(algorithm='auto', leaf_si...
# 3  KNeighborsClassifier(algorithm='auto', leaf_si...
# 4  KNeighborsClassifier(algorithm='auto', leaf_si...

# %%
allresults = resultsNOBG.groupby(['Classifier','Count']).mean().unstack(0)

# %%
allresults.head()
# Out:
#            Cycle                Split                Train Acc             \
# Classifier   KNN   NN   RF  SVM   KNN   NN   RF  SVM       KNN         NN
# Count
# 10           2.0  2.0  2.0  2.0   4.5  4.5  4.5  4.5     100.0  93.436563
# 20           2.0  2.0  2.0  2.0   4.5  4.5  4.5  4.5     100.0  97.631822
# 30           2.0  2.0  2.0  2.0   4.5  4.5  4.5  4.5     100.0  98.509791
# 40           2.0  2.0  2.0  2.0   4.5  4.5  4.5  4.5     100.0  99.130840
# Full         2.0  2.0  2.0  2.0   4.5  4.5  4.5  4.5     100.0  99.014202
#
#                ...      F1 Score           Train Time (ms)               \
# Classifier     ...            RF       SVM             KNN           NN
# Count          ...
# 10             ...      5.593800  5.766327        9.903198  5245.248920
# 20             ...      5.748782  5.844160       13.003769  4348.886049
# 30             ...      5.763282  5.874418       16.415712  4063.191494
# 40             ...      5.777435  5.919736       22.033315  3785.030717
# Full           ...      5.771576  5.920864       24.823647  3621.614230
#
#                                     clfs per ms                           \
# Classifier          RF          SVM         KNN           NN          RF
# Count
# 10          297.166847  1446.726069  533.401920  1729.262957  589.626240
# 20          375.949692   357.612975  284.763446  1799.204295  542.704794
# 30          465.280729   286.356458  195.003639  1762.059950  592.861645
# 40          526.426509   296.854529  126.625640  1578.724043  561.129617
# Full        501.606649   312.870129  107.462163  1810.612080  594.322289
#
#
# Classifier         SVM
# Count
# 10          936.004794
# 20          601.692297
# 30          403.843392
# 40          400.869949
# Full        369.615930
#
# [5 rows x 28 columns]

# %%
fig, axis = plt.subplots(nrows=2, ncols=2,figsize=(16,10)) 
plt.tight_layout(pad=3.4, w_pad=3.5, h_pad=6)

colors = ['red', 'g', 'blue', 'black']
styles=['rs-', 'go--', 'b^-.','ks--']
linewidths = [2, 2, 3,2]


bplota = allresults.plot(ax = axis[0][0], y='Test Acc',style=styles)
bplotb = allresults.plot(ax = axis[0][1], y='F1 Score',style=styles)
bplotd = allresults.plot(ax = axis[1][0], y='Train Time (ms)',style=styles)
bplote = allresults.plot(ax = axis[1][1], y='clfs per ms',style=styles)




fig.texts = [] #flush the old super titles
plt.suptitle('') 

axis[0][0].set_title('Test Accuracy',fontsize=15)
axis[0][0].set_ylabel('Accuracy %',fontsize=15)
axis[0][0].set_ylim(80,100)
axis[0][1].set_title('F1 Score',fontsize=15)
axis[0][1].set_ylabel('F1 Score',fontsize=15)
axis[0][1].set_ylim(5,6)
axis[1][0].set_title('Training Time',fontsize=15)
axis[1][0].set_ylabel('Time (ms)',fontsize=15)
#axis[1][0].set_ylim(0.5,2)
axis[1][1].set_title('Classification Per MilliSecond',fontsize=15)
axis[1][1].set_ylabel('Classification per ms',fontsize=15)
#axis[1][1].set_ylim(10,25)
#will add SLA % and Communicated Size
labels = [["(a)",'(b)'],['(c)',"(d)"]]
for (n_row, n_col), axes in np.ndenumerate(axis):
    axes.set_xlabel(labels[n_row][n_col],fontsize=15)
    #axes.legend_.remove()
    for tick in axes.get_xticklabels():
        tick.set_rotation(0)
    for i, l in enumerate(axes.lines):
        plt.setp(l, linewidth=linewidths[i])

#fig.savefig('BarPolicies.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
copy = resultsNOBG.copy()
copy = copy[copy['Count']=='10'].groupby(['Classifier']).mean()
copy.head(5)
# Out:
#             Cycle  Split   Train Acc   Test Acc  F1 Score  Train Time (ms)  \
# Classifier
# KNN           2.0    4.5  100.000000  93.433053  5.639546         9.903198
# NN            2.0    4.5   93.436563  91.701603  5.495778      5245.248920
# RF            2.0    4.5   99.960078  92.971373  5.593800       297.166847
# SVM           2.0    4.5   98.726894  95.977434  5.766327      1446.726069
#
#             clfs per ms
# Classifier
# KNN          533.401920
# NN          1729.262957
# RF           589.626240
# SVM          936.004794

# %%
Solar = resultsSolar.copy()
Solar = Solar[Solar['Count']=='10'].groupby(['Classifier']).mean()
Solar.head(5)
# Out:
#             Cycle  Split   Train Acc   Test Acc  F1 Score  Train Time (ms)  \
# Classifier
# KNN           2.0    4.5  100.000000  95.172240  5.733270        10.120905
# NN            2.0    4.5   91.551618  90.596051  5.486163      4568.574412
# RF            2.0    4.5   99.955301  93.770567  5.668683       296.568104
# SVM           2.0    4.5   95.296528  94.012471  5.699872      1641.810095
#
#             clfs per ms
# Classifier
# KNN          677.462217
# NN          1830.320794
# RF           569.903511
# SVM          642.688953

# %%
allSolarresults = resultsSolar.groupby(['Classifier','Count']).mean().unstack(0)
fig, axis = plt.subplots(nrows=2, ncols=2,figsize=(16,10)) 
plt.tight_layout(pad=3.4, w_pad=3.5, h_pad=6)

colors = ['red', 'g', 'blue', 'black']
styles=['rs-', 'go--', 'b^-.','ks--']
linewidths = [2, 2, 3,2]


bplota = allSolarresults.plot(ax = axis[0][0], y='Test Acc',style=styles)
bplotb = allSolarresults.plot(ax = axis[0][1], y='F1 Score',style=styles)
bplotd = allSolarresults.plot(ax = axis[1][0], y='Train Time (ms)',style=styles)
bplote = allSolarresults.plot(ax = axis[1][1], y='clfs per ms',style=styles)




fig.texts = [] #flush the old super titles
plt.suptitle('') 

axis[0][0].set_title('Test Accuracy',fontsize=15)
axis[0][0].set_ylabel('Accuracy %',fontsize=15)
axis[0][0].set_ylim(80,100)
axis[0][1].set_title('F1 Score',fontsize=15)
axis[0][1].set_ylabel('F1 Score',fontsize=15)
axis[0][1].set_ylim(5,6)
axis[1][0].set_title('Training Time',fontsize=15)
axis[1][0].set_ylabel('Time (ms)',fontsize=15)
#axis[1][0].set_ylim(0.5,2)
axis[1][1].set_title('Classification Per MilliSecond',fontsize=15)
axis[1][1].set_ylabel('Classification per ms',fontsize=15)
#axis[1][1].set_ylim(10,25)
#will add SLA % and Communicated Size
labels = [["(a)",'(b)'],['(c)',"(d)"]]
for (n_row, n_col), axes in np.ndenumerate(axis):
    axes.set_xlabel(labels[n_row][n_col],fontsize=15)
    #axes.legend_.remove()
    for tick in axes.get_xticklabels():
        tick.set_rotation(0)
    for i, l in enumerate(axes.lines):
        plt.setp(l, linewidth=linewidths[i])

#fig.savefig('BarPolicies.png', dpi=300, bbox_inches='tight', transparent=True)
